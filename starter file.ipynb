# %%
import os
from openai import AzureOpenAI

endpoint = "https://chr-umn-hackathon-resource.cognitiveservices.azure.com/"
model_name = "gpt-5-mini"
deployment = "gpt-5-mini"

subscription_key = "2RT8mQ01jQmMrZwiHczy75cckYTP2Kii9McSvgDCGFJ8Q7P37vVwJQQJ99BJACYeBjFXJ3w3AAAAACOGxEp9"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_completion_tokens=16384,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# Great — Paris has so much to offer. A few quick questions to help tailor suggestions: How many days will you be there, and what do you like most (art, history, food, shopping, romance, families/kids, nightlife)?
#
# Meanwhile, here’s a compact guide to must-sees and choices by interest:
#
# Top iconic sights
# - Eiffel Tower — go up for views (book timed tickets) or enjoy picnic views on the Champ de Mars.
# - Louvre — world’s largest art museum (book a timed entry); don’t try to see everything — prioritize sections (Mona Lisa, Greek/Oriental antiquities).
# - Notre-Dame/Île de la Cité — the cathedral area and Sainte-Chapelle’s stained glass.
# - Arc de Triomphe & Champs-Élysées — climb the arch for a great view down the avenue.
# - Montmartre & Sacré-Cœur — cobbled streets, artists’ square, sunset views.
# - Musée d’Orsay — Impressionist masterpieces in a converted train station.
# - Seine river cruise — lovely at sunset; excellent orientation for first-time visitors.
#
# Neighborhoods worth exploring
# - Le Marais — boutiques, Jewish quarter falafel, trendy cafés, Musée Carnavalet and Picasso Museum.
# - Latin Quarter & Saint-Germain-des-Prés — narrow streets, bookshops (Shakespeare & Company), cafés, lively atmosphere.
# - Canal Saint‑Martin — relaxed cafés, good for a stroll or picnic.
# - Opéra / Grands Magasins — Galeries Lafayette & Printemps for shopping and rooftop views.
#
# Other museums & unique spots
# - Centre Pompidou — modern art + rooftop panorama.
# - Musée Rodin — sculpture garden (very pleasant).
# - Musée Picasso — excellent if you love Picasso.
# - Catacombs — macabre and popular; book ahead.
# - Musée de l’Orangerie — Monet’s Water Lilies.
# - Palais Garnier (Opéra) — grand interior tours.
#
# Day trips
# - Palace of Versailles — gardens and Hall of Mirrors (allow a full day).
# - Giverny — Monet’s house and gardens (spring/summer).
# - Loire Valley castles or Champagne region if you want wine and châteaux.
#
# Practical tips
# - Book timed tickets for major museums and the Eiffel Tower to avoid long lines.
# - Consider a Paris Museum Pass if you plan to visit many attractions.
# - Metro is fast and extensive; buy single tickets (t+) or a multi-day pass (Navigo or Paris Visite depending on length).
# - Watch for pickpockets in tourist areas and on crowded metro lines.
# - Many museums close one weekday — check opening days (e.g., Louvre closed Tuesday, Musée d’Orsay closed Monday).
# - Cash/credit: cards accepted widely; contactless payments are common.
# - Dining: try bakeries (croissant, pain au chocolat), cheese, charcuterie, bistros, and make reservations for popular restaurants. Tipping isn’t mandatory (service often included) but small extra is appreciated.
#
# Quick sample itineraries
# - 1 day: Morning at Louvre, walk through Tuileries to Place de la Concorde, Champs-Élysées to Arc de Triomphe, late afternoon Eiffel Tower + Seine cruise at dusk.
# - 3 days: Day 1 — Louvre + Île de la Cité (Sainte-Chapelle), Latin Quarter; Day 2 — Musée d’Orsay + Saint‑Germain + Luxembourg Gardens + evening in Montmartre/Sacré‑Cœur; Day 3 — Le Marais + Centre Pompidou + Canal Saint‑Martin or Versailles day trip.
# - Family-friendly: Luxembourg Gardens playground, Cité des Sciences, Jardin d’Acclimatation, boat on the Seine.
#
# Food suggestions
# - Café culture: sit and watch the world go by — try café crème, espresso.
# - Boulangerie: baguette and croissants.
# - Markets: Rue Cler or Marché Bastille for fresh produce and picnic supplies.
# - Sweet treats: macarons (Ladurée, Pierre Hermé), patisseries.
# - Regional dining: try a bistro for steak frites, a crêperie for savory crêpes.
#
# If you tell me how long you’ll be in Paris and your main interests, I can draft a personalized day-by-day plan. Enjoy — Paris is best explored slowly and on foot when you can.
